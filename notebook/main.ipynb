# %%
# !pip install pandas transformers torch

# %%
# !pip install sentence_transformers
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.0/86.0 kB 3.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for sentence_transformers: filename=sentence_transformers-2.2.2-py3-none-any.whl size=125926 sha256=f50eeeac23a16ec1dfdade8c8af2ebbc3ca6cfbd0fbd5072ec34fcdccf83fc6e
#   Stored in directory: /root/.cache/pip/wheels/62/f2/10/1e606fd5f02395388f74e7462910fe851042f97238cbbd902f
# Successfully built sentence_transformers
# ...

# %%
import pandas as pd
df = pd.read_csv('/kaggle/input/wechatbot/wechatbot.csv')

# %%
df.head()
# Out:
#    Unnamed: 0                                               Name  \
# 0           0            Python Playground: Create a Memory Game
# 1           1                           LEARN SCRATCH PROGRAMING
# 2           2                   Roblox Programming For Beginners
# 3           3            Web Development Pro: Intermediate Level
# 4           4  AI Disruption: Top Entrepreneurs Harnessing AI...
#
#                                          Description  Session_Price  Lessons  \
# 0  Python Playground: Create a Memory Game is a b...             20        8
# 1  Scratch Course is the foundation of coding and...             20       16
# 2  Explore the dynamic universe of game developme...             30       15
# 3  Ready to unlock the full potential of web deve...             30        8
# 4  Understand the role and potential of AI in ent...             22        7
#
#              Duration  Price
# 0              1 hour    160
# 1    1 hr per session    320
# ...

# %%
from sentence_transformers import SentenceTransformer

model = SentenceTransformer("BAAI/bge-large-en-v1.5")

# %%
import pandas as pd
import numpy as np
import torch
from transformers import BertTokenizer, BertModel
from sklearn.metrics.pairwise import cosine_similarity

from sentence_transformers import SentenceTransformer

model = SentenceTransformer("BAAI/bge-large-en-v1.5")

# Encode the 'text' column
df['embedding'] = df['Description'].apply( lambda X: model.encode(X))
# Out:
# ...
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
df.head()
# Out:
#    Unnamed: 0                                               Name  \
# 0           0            Python Playground: Create a Memory Game
# 1           1                           LEARN SCRATCH PROGRAMING
# 2           2                   Roblox Programming For Beginners
# 3           3            Web Development Pro: Intermediate Level
# 4           4  AI Disruption: Top Entrepreneurs Harnessing AI...
#
#                                          Description  Session_Price  Lessons  \
# 0  Python Playground: Create a Memory Game is a b...             20        8
# 1  Scratch Course is the foundation of coding and...             20       16
# 2  Explore the dynamic universe of game developme...             30       15
# 3  Ready to unlock the full potential of web deve...             30        8
# 4  Understand the role and potential of AI in ent...             22        7
#
#              Duration  Price  \
# 0              1 hour    160
# 1    1 hr per session    320
# ...

# %%
df['embedding'][0].reshape(-1,1)

df['embedding'] = df['embedding'].apply(lambda x: x.reshape(-1,1) )

# %%
import pandas as pd
from sklearn.metrics.pairwise import cosine_similarity
from sentence_transformers import SentenceTransformer

# User query
user_query = "what is <Web Development Pro: Intermediate Level> is about?"

# Generate embedding for the user query
user_embedding = model.encode(user_query).reshape(1, -1)

# Calculate cosine similarities
similarities = []
for emb in df['embedding']:
    sim = cosine_similarity(user_embedding, emb.reshape(1, -1))
    similarities.append(sim[0][0])

df['similarity'] = similarities

# Get top-k similar rows
top_k = 5  # Change k value as needed
top_k_df = df.nlargest(top_k, 'similarity')

# Show the top-k rows
# print(top_k_df[['Title', 'Description', 'similarity']])
# Out:
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
top_k_df.shape[0]
# Out:
# 5

# %%
top_k_df['Name'].iloc[0]
# Out:
# 'Web Development Pro: Intermediate Level'

# %%
context_string = ''
for i in range(top_k_df.shape[0]):
  context_string =  context_string + f"Name : {top_k_df['Name'].iloc[i]} \n\n Description: {top_k_df['Description'].iloc[i]} \n\n Session_price: {top_k_df['Session_Price'].iloc[i]} \n\n Lessons:{top_k_df['Lessons'].iloc[i]} \n\n Duration:{top_k_df['Duration'].iloc[i]} \n\n Price:{top_k_df['Price'].iloc[i]}"

# %%
print(context_string)
# Out:
# Name : Web Development Pro: Intermediate Level
#
#  Description: Ready to unlock the full potential of web development? Join our "Intermediate Web Development Mastery" course and embark on a transformative journey. Learn advanced HTML, CSS, and JavaScript, delve into front-end frameworks like React and Vue.js, explore the world of back-end development with Node.js, Python, and more, and gain mastery over databases and data management. But that's not all! Discover the art of building APIs and fortify your web applications against common security vulnerabilities. Learn to deploy your creations to the web and implement automated testing and deployment workflows with CI/CD. Enroll now to secure your spot in this comprehensive course. Take the next step in your web development journey and empower yourself with the skills and knowledge needed to create dynamic, secure, and scalable web applications. Your future as a proficient web developer awaits – join us today and make it a reality!
#
# ...

# %%
#llama2
# !pip install transformers torch accelerate
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# ...

# %%
from huggingface_hub import notebook_login
notebook_login()

# %%
#llama2
from transformers import AutoTokenizer
import transformers
import torch

model = "meta-llama/Llama-2-7b-chat-hf" # meta-llama/Llama-2-7b-hf

tokenizer = AutoTokenizer.from_pretrained(model, use_auth_token=True)
# Out:
# /opt/conda/lib/python3.10/site-packages/transformers/models/auto/tokenization_auto.py:640: FutureWarning: The `use_auth_token` argument is deprecated and will be removed in v5 of Transformers.
#   warnings.warn(
# ...

# %%
#llama2
from transformers import pipeline

llama_pipeline = pipeline(
    "text-generation",  # LLM task
    model=model,
    torch_dtype=torch.float16,
    device_map="auto",
)
# Out:
# ...
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# ...

# %%
#llama2
def get_llama_response(prompt: str) -> None:
    """
    Generate a response from the Llama model.

    Parameters:
        prompt (str): The user's input/question for the model.

    Returns:
        None: Prints the model's response.
    """
    sequences = llama_pipeline(
        prompt,
        do_sample=True,
        top_k=10,
        num_return_sequences=1,
        eos_token_id=tokenizer.eos_token_id,
        max_length=256,
    )
    print("Chatbot:", sequences[0]['generated_text'])



# prompt = 'I liked "Breaking Bad" and "Band of Brothers". Do you have any recommendations of other shows I might like?\n'
# get_llama_response(prompt_fin)

# %%
question = "Summarize about Web Development Pro: Intermediate Level course "
template = """<s>[INST] You are a helpful, respectful and honest assistant. Answer exactly in few words from the context
Answer the question below from context below :
{context}
{question} [/INST] </s>"""
prompt_fin = template.format(context = context_string, question = question)

# %%
prompt_fin = """<s>[INST] You are a helpful, respectful and honest assistant. Answer exactly in few words from the context
Answer the question below from context below :
Name : Web Development Pro: Intermediate Level

 Description: Ready to unlock the full potential of web development? Join our "Intermediate Web Development Mastery" course and embark on a transformative journey. Learn advanced HTML, CSS, and JavaScript, delve into front-end frameworks like React and Vue.js, explore the world of back-end development with Node.js, Python, and more, and gain mastery over databases and data management. But that's not all! Discover the art of building APIs and fortify your web applications against common security vulnerabilities. Learn to deploy your creations to the web and implement automated testing and deployment workflows with CI/CD. Enroll now to secure your spot in this comprehensive course. Take the next step in your web development journey and empower yourself with the skills and knowledge needed to create dynamic, secure, and scalable web applications. Your future as a proficient web developer awaits – join us today and make it a reality!

 Session_price: 30

 Lessons:8

 Duration:1 hour per session

 Price:240Name : Web Development from scratch

 Description: Unlock the boundless potential of web development with our "Web Development Essentials" course. Whether you're a beginner looking to create your first website or an enthusiast eager to refine your skills, this comprehensive journey is tailored just for you. Learn the building blocks of the web: HTML and CSS; infuse life into your pages with JavaScript; conquer responsive design; and master essential tools like Git and command-line usage. As you embark on this transformative learning experience, you'll gain the knowledge and confidence needed to craft stunning, interactive web content. Don't let the digital world pass you by – enroll now, and let's build the future of the web together! Your journey begins here. **Enroll Today:** Take your first step towards becoming a proficient web developer. Enroll now to secure your spot in the "Web Development Essentials" course. Join a community of learners, unlock the secrets of web development, and embark on a path to creating web experiences that captivate and inspire. Don't wait; your future in web development starts with a single click. Join us today!

 Session_price: 30

 Lessons:6

 Duration:1 hour per session

 Price:180Name : Advanced Roblox Scripting Workshop

 Description: "Are you ready to unlock the full potential of your Roblox game development skills? Join our Intermediate Roblox Game Development and Scripting course today and embark on a transformative journey that will elevate your game development prowess to new heights. In this comprehensive 14-session program, you'll dive deep into the intricacies of Roblox game creation, mastering advanced scripting techniques, designing captivating user interfaces, implementing sophisticated character controls, and exploring the world of data persistence. But that's not all! We'll guide you through the complexities of multiplayer networking, help you create immersive audiovisual effects, and teach you the secrets of performance optimization. You'll even gain proficiency in collaboration with version control systems, a skill that's essential for real-world game development teams. Throughout the course, you'll put your newfound knowledge into practice with hands-on projects, receive constructive feedback from your peers, and polish your games to a professional standard. By the end, you'll not only have a portfolio of impressive Roblox projects but also the confidence and skills to create captivating, multiplayer experiences that set you apart in the world of game development. Don't miss out on this unique opportunity to showcase your expertise and join the thriving Roblox developer community. Enroll now to kickstart your journey towards becoming a highly skilled Roblox game developer, and start crafting immersive, multiplayer games that captivate players and potential employers alike. Your future in game development begins here – elevate your game, enroll today!"

 Session_price: 30

 Lessons:14

 Duration:1 hour per session

 Price:420Name : Java Project-Based Course

 Description: Java Project-Based Course for Intermediate Level Students ;Overview: This course is designed for intermediate level students who want to build practical Java projects while learning advanced Java concepts. Over the course of one week, students will build 7 real-world Java projects. Day 1: Quiz ApplicationDay 2: File Manager;Day 3: Weather Application;Day 4: Social Network; Day 5: Image Editor;Day 6: Stock Trading System Day 7: E-commerce Site

 Session_price: 20

 Lessons:7

 Duration:1 hour

 Price:140Name : PYTHON PROGRAMMING-INTERMEDIATE

 Description: Take your python skills to the next level and start building real applications.
Python is a programming language is well-known for being easy and simple to use, mainly because it allows the programmers to use a method rich in styles, instead of doing in a complex way. It also features the possibility of extending over other customization interfaces.
In this course, you will learn in depth the most important Python language topics for the intermediate level. We will also give practice questions and Sufficient amount of fundamental knowledge will be provided which is necessary enough to pursue the advance Python Courses.

MAIN FEATURES OF THE PROGRAM:
• One on One Live Interactive Sessions with verified Instructor
• Customized Curriculum according to your kid’s progress
• Simple and interesting assignments for easy learning
• Class Tracking Report on daily basis.
• Strong focus on Learning with Fun
• Complete access of the study materials and Power Point Slides.

 Session_price: 20

 Lessons:16

 Duration:1 hour per session

 Price:320
Summarize about Web Development Pro: Intermediate Level course  [/INST] </s>"""

# %%
get_llama_response(prompt_fin)
# Out:
# /opt/conda/lib/python3.10/site-packages/transformers/generation/utils.py:1268: UserWarning: Input length of input_ids is 1400, but `max_length` is set to 256. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
#   warnings.warn(
# Chatbot: <s>[INST] You are a helpful, respectful and honest assistant. Answer exactly in few words from the context
# Answer the question below from context below :
# Name : Web Development Pro: Intermediate Level
#
# ...
